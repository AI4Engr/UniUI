# %%
import importlib
import quick_start
importlib.reload(quick_start)

from quick_start import create_bmi_ui
from uniui.display import show_ui

layout = create_bmi_ui("jupyter")
show_ui(layout, "BMI Calculator")
# Out:
# JupyterVBoxLayout(children=(HTML(value='\n    <style>\n    .uniui-themed { background-color: #0f1117 !importan…

# %%
from sysmon import create_sysmon_ui
from uniui.display import show_ui
show_ui(create_sysmon_ui("jupyter"), "System Monitor", 620, 520)
# Out:
# JupyterVBoxLayout(children=(JupyterGroupBox(children=(HTML(value='<b style="color:#1a1a2e;font-size:10pt">CPU<…

# %%
from tests.calculator import create_calculator_ui
from uniui.display import show_ui
show_ui(create_calculator_ui("jupyter"), "Calculator", 400, 600)
# Out:
# Running cells with 'base (Python 3.12.11)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n base ipykernel --update-deps --force-reinstall'

# %%
import importlib
import tests.credit_card
importlib.reload(tests.credit_card)

from tests.credit_card import create_credit_card_ui
from uniui.display import show_ui
show_ui(create_credit_card_ui("jupyter"), "Credit Card Form", 500, 600)
# Out:
# JupyterVBoxLayout(children=(HTML(value='\n    <style>\n    .uniui-themed { background-color: #0f1117 !importan…

# %%
import importlib
import tests.test_ui
importlib.reload(tests.test_ui)

from tests.test_ui import create_test_ui
from uniui.display import show_ui
show_ui(create_test_ui("jupyter", "simple"), "简单测试", 600, 450)
# Out:
# JupyterVBoxLayout(children=(JupyterHBoxLayout(children=(JupyterLabel(value='Widget Test', layout=Layout(flex='…
